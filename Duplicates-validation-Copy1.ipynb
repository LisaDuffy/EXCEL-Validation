# %%
import pandas as pd

test_file = 'TEST.xlsx'

data = pd.read_excel(test_file, header=0)

print(data)

# Print All duplicate rows based on one column 
duplicateRowsDF = data[data.duplicated(['Code'])]
duplicateRowsDF.to_excel('Duplicate_Rows.xlsx', index = False)
# Out:
#           Code        EAN No.  MPN                          Product Name  \
# 0      20-AW-N  5392000073425  NaN         Joint- It Simple Neutral 20kg
# 1      20-AW-G  5392000073470  NaN            Joint- It Simple Grey 20kg
# 2     20-AW-DG  5392000073487  NaN       Joint- It Simple Dark Grey 20kg
# 3      20-AW-B  5391535770106  NaN           Joint- It Simple Black 20kg
# 4    12.5-AW-N  5392000073449  NaN       Joint- It Simple Neutral 12.5kg
# 5    12.5-AW-G  5392000073456  NaN          Joint- It Simple Grey 12.5kg
# 6   12.5-AW-DG  5392000073463  NaN     Joint- It Simple Dark Grey 12.5kg
# 7    12.5-AW-B  5391535770113  NaN         Joint- It Simple Black 12.5kg
# 8      JOIFN20  5391535770014  NaN           Joint- It Fine Neutral 20kg
# 9      JOIFG20  5391535770007  NaN              Joint- It Fine Grey 20kg
# 10       PRES1  5391535770045  NaN             Joint- It Premium Seal 1L
# 11       PRES5  5391535770052  NaN             Joint- It Premium Seal 5L
# ...
